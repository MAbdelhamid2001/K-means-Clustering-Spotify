# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('ltrain.csv')

# %%
data
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.702   0.701    1    -8.724     1       0.0769      0.001560
# 1            0.875   0.907    4   -11.434     0       0.1660      0.016600
# 2            0.788   0.620    1    -8.117     1       0.0522      0.000009
# 3            0.739   0.872   11    -4.059     0       0.3330      0.021700
# 4            0.796   0.922    9    -8.882     0       0.1190      0.003780
# ...            ...     ...  ...       ...   ...          ...           ...
# 4782         0.596   0.973   11    -5.151     0       0.0706      0.000003
# 4783         0.736   0.848    1   -11.012     0       0.0428      0.009070
# 4784         0.654   0.750    8    -7.509     0       0.1050      0.244000
# 4785         0.745   0.630    1    -6.474     1       0.2120      0.016200
# 4786         0.571   0.834    8   -12.281     0       0.0494      0.032100
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0               0.9220    0.1120   0.2190  128.001       408750
# 1               0.0000    0.3600   0.7430  188.010       340133
# 2               0.8910    0.0792   0.0554  128.008       371148
# 3               0.0000    0.2600   0.6840  190.168       238746
# 4               0.8740    0.1100   0.2510  130.011       341038
# ...                ...       ...      ...      ...          ...
# 4782            0.8690    0.0704   0.1110  139.995       609867
# 4783            0.9080    0.0737   0.0391  128.006       469949
# 4784            0.0178    0.1670   0.5570  185.546       272507
# 4785            0.0000    0.4840   0.5100  193.918       165793
# 4786            0.8440    0.2990   0.1720  132.994       393383
#
#       time_signature  genre_label
# 0                  4            1
# 1                  4            0
# 2                  4            1
# 3                  4            0
# 4                  3            1
# ...              ...          ...
# 4782               4            1
# 4783               4            1
# 4784               4            0
# 4785               4            0
# 4786               4            1
#
# [4787 rows x 14 columns]

# %%
data.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   4787.000000  4787.000000  4787.000000  4787.000000  4787.000000
# mean       0.707160     0.723421     5.645916    -8.149476     0.550658
# std        0.118878     0.168107     3.637997     2.870430     0.497479
# min        0.197000     0.027900     0.000000   -26.172000     0.000000
# 25%        0.640000     0.614000     2.000000    -9.898000     0.000000
# 50%        0.725000     0.742000     6.000000    -7.980000     1.000000
# 75%        0.792000     0.856000     9.000000    -6.199000     1.000000
# max        0.978000     1.000000    11.000000    -0.067000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  4787.000000   4787.000000       4787.000000  4787.000000  4787.000000
# mean      0.143136      0.117006          0.427042     0.180915     0.361400
# std       0.123852      0.185777          0.430969     0.149959     0.257934
# min       0.022700      0.000001          0.000000     0.021900     0.018700
# 25%       0.051400      0.002925          0.000000     0.099050     0.125000
# 50%       0.078500      0.028600          0.171000     0.113000     0.322000
# 75%       0.226000      0.148000          0.880000     0.206000     0.568000
# max       0.944000      0.978000          0.972000     0.973000     0.975000
#
#              tempo    duration_ms  time_signature  genre_label
# count  4787.000000    4787.000000     4787.000000  4787.000000
# mean    146.303606  313687.591602        3.963860     0.494882
# std      26.388446  108222.803329        0.304839     0.500026
# min      95.622000   38333.000000        1.000000     0.000000
# 25%     127.016000  224366.500000        4.000000     0.000000
# 50%     132.008000  306383.000000        4.000000     0.000000
# 75%     171.205000  401555.500000        4.000000     1.000000
# max     206.247000  894386.000000        5.000000     1.000000

# %%
data.corr()
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000 -0.081680  0.021580 -0.028742 -0.008728
# energy               -0.081680  1.000000  0.013632  0.346455  0.014827
# key                   0.021580  0.013632  1.000000 -0.006646 -0.276227
# loudness             -0.028742  0.346455 -0.006646  1.000000 -0.025301
# mode                 -0.008728  0.014827 -0.276227 -0.025301  1.000000
# speechiness          -0.038615 -0.200862  0.009422  0.231953 -0.056893
# acousticness         -0.164985 -0.413887  0.007262 -0.046014 -0.037084
# instrumentalness      0.073861  0.391084  0.012515 -0.409594  0.053256
# liveness             -0.167556  0.019043  0.012400  0.133987  0.032326
# valence               0.130955 -0.099249  0.040457  0.376911 -0.063865
# tempo                -0.033579 -0.178755 -0.000225  0.300073 -0.035513
# duration_ms           0.092469  0.331336  0.014882 -0.310566  0.036626
# time_signature        0.084351 -0.027678 -0.019643  0.040676 -0.009281
# genre_label           0.076450  0.413562  0.018013 -0.400621  0.051650
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# danceability        -0.038615     -0.164985          0.073861 -0.167556
# energy              -0.200862     -0.413887          0.391084  0.019043
# key                  0.009422      0.007262          0.012515  0.012400
# loudness             0.231953     -0.046014         -0.409594  0.133987
# mode                -0.056893     -0.037084          0.053256  0.032326
# speechiness          1.000000      0.277720         -0.611924  0.198018
# acousticness         0.277720      1.000000         -0.392416  0.057867
# instrumentalness    -0.611924     -0.392416          1.000000 -0.222597
# liveness             0.198018      0.057867         -0.222597  1.000000
# valence              0.484623      0.213211         -0.633993  0.153416
# tempo                0.507443      0.206508         -0.629496  0.167511
# duration_ms         -0.467424     -0.377171          0.773793 -0.162914
# time_signature       0.054709      0.005421         -0.050034  0.020341
# genre_label         -0.613509     -0.420190          0.965642 -0.211859
#
#                    valence     tempo  duration_ms  time_signature  genre_label
# danceability      0.130955 -0.033579     0.092469        0.084351     0.076450
# energy           -0.099249 -0.178755     0.331336       -0.027678     0.413562
# key               0.040457 -0.000225     0.014882       -0.019643     0.018013
# loudness          0.376911  0.300073    -0.310566        0.040676    -0.400621
# mode             -0.063865 -0.035513     0.036626       -0.009281     0.051650
# speechiness       0.484623  0.507443    -0.467424        0.054709    -0.613509
# acousticness      0.213211  0.206508    -0.377171        0.005421    -0.420190
# instrumentalness -0.633993 -0.629496     0.773793       -0.050034     0.965642
# liveness          0.153416  0.167511    -0.162914        0.020341    -0.211859
# valence           1.000000  0.504128    -0.521324        0.050430    -0.638876
# tempo             0.504128  1.000000    -0.510303        0.018488    -0.650021
# duration_ms      -0.521324 -0.510303     1.000000       -0.029865     0.794756
# time_signature    0.050430  0.018488    -0.029865        1.000000    -0.049876
# genre_label      -0.638876 -0.650021     0.794756       -0.049876     1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4787 entries, 0 to 4786
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      4787 non-null   float64
#  1   energy            4787 non-null   float64
#  2   key               4787 non-null   int64
#  3   loudness          4787 non-null   float64
#  4   mode              4787 non-null   int64
#  5   speechiness       4787 non-null   float64
#  6   acousticness      4787 non-null   float64
#  7   instrumentalness  4787 non-null   float64
#  8   liveness          4787 non-null   float64
#  9   valence           4787 non-null   float64
#  10  tempo             4787 non-null   float64
#  11  duration_ms       4787 non-null   int64
#  12  time_signature    4787 non-null   int64
#  13  genre_label       4787 non-null   int64
# dtypes: float64(9), int64(5)
# memory usage: 523.7 KB

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature', 'genre_label'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1)
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
def scale(x):
    return ((x-np.mean(x))/np.std(x))

# %%
xtrain=data.drop('genre_label',axis=1)
ytrain=data['genre_label']

# %%
xtrain
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.702   0.701    1    -8.724     1       0.0769      0.001560
# 1            0.875   0.907    4   -11.434     0       0.1660      0.016600
# 2            0.788   0.620    1    -8.117     1       0.0522      0.000009
# 3            0.739   0.872   11    -4.059     0       0.3330      0.021700
# 4            0.796   0.922    9    -8.882     0       0.1190      0.003780
# ...            ...     ...  ...       ...   ...          ...           ...
# 4782         0.596   0.973   11    -5.151     0       0.0706      0.000003
# 4783         0.736   0.848    1   -11.012     0       0.0428      0.009070
# 4784         0.654   0.750    8    -7.509     0       0.1050      0.244000
# 4785         0.745   0.630    1    -6.474     1       0.2120      0.016200
# 4786         0.571   0.834    8   -12.281     0       0.0494      0.032100
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0               0.9220    0.1120   0.2190  128.001       408750
# 1               0.0000    0.3600   0.7430  188.010       340133
# 2               0.8910    0.0792   0.0554  128.008       371148
# 3               0.0000    0.2600   0.6840  190.168       238746
# 4               0.8740    0.1100   0.2510  130.011       341038
# ...                ...       ...      ...      ...          ...
# 4782            0.8690    0.0704   0.1110  139.995       609867
# 4783            0.9080    0.0737   0.0391  128.006       469949
# 4784            0.0178    0.1670   0.5570  185.546       272507
# 4785            0.0000    0.4840   0.5100  193.918       165793
# 4786            0.8440    0.2990   0.1720  132.994       393383
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  3
# ...              ...
# 4782               4
# 4783               4
# 4784               4
# 4785               4
# 4786               4
#
# [4787 rows x 13 columns]

# %%
xtrain=scale(xtrain)
df=xtrain

# %%
xtrain
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 0        -0.043412 -0.133386 -1.277187 -0.200173  0.903332    -0.534861
# 1         1.412008  1.092149 -0.452471 -1.144382 -1.107012     0.184624
# 2         0.680091 -0.615271 -1.277187  0.011315  0.903332    -0.734314
# 3         0.267863  0.883927  1.471866  1.425188 -1.107012     1.533154
# 4         0.747394  1.181386  0.922055 -0.255223 -1.107012    -0.194902
# ...            ...       ...       ...       ...       ...          ...
# 4782     -0.935172  1.484796  1.471866  1.044718 -1.107012    -0.585733
# 4783      0.242624  0.741146 -1.277187 -0.997350 -1.107012    -0.810219
# 4784     -0.447228  0.158124  0.647150  0.223152 -1.107012    -0.307952
# 4785      0.318340 -0.555779 -1.277187  0.583763  0.903332     0.556076
# 4786     -1.145493  0.657857  0.647150 -1.439490 -1.107012    -0.756924
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 0        -0.621487          1.148597 -0.459607 -0.552140 -0.693657
# 1        -0.540522         -0.990991  1.194354  1.479604  1.580644
# 2        -0.629835          1.076658 -0.678357 -1.186478 -0.693391
# 3        -0.513066         -0.990991  0.527434  1.250839  1.662431
# 4        -0.609536          1.037208 -0.472946 -0.428064 -0.617479
# ...            ...               ...       ...       ...       ...
# 4782     -0.629871          1.025605 -0.737046 -0.970896 -0.239092
# 4783     -0.581058          1.116108 -0.715038 -1.249679 -0.693467
# 4784      0.683655         -0.949684 -0.092801  0.758412  1.487260
# 4785     -0.542675         -0.990991  2.021334  0.576176  1.804554
# 4786     -0.457079          0.967590  0.787533 -0.734376 -0.504425
#
#       duration_ms  time_signature
# 0        0.878487        0.118565
# 1        0.244386        0.118565
# 2        0.531001        0.118565
# 3       -0.692547        0.118565
# 4        0.252750       -3.162197
# ...           ...             ...
# 4782     2.737042        0.118565
# 4783     1.444037        0.118565
# 4784    -0.380557        0.118565
# 4785    -1.366718        0.118565
# 4786     0.736478        0.118565
#
# [4787 rows x 13 columns]

# %%
#applying elbow method to find optimal number of K clusters
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(data)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
#applying k means alogrithm
#after applying elbow method we find that the best k is =2
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=2)

# %%
KMeans
# Out:
# sklearn.cluster._kmeans.KMeans

# %%
labels = kmeans.predict(data)
centroids = kmeans.cluster_centers_

# %%
labels
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score
print("Accuracy Score: ",accuracy_score(ytrain,labels)*100)
# Out:
# Accuracy Score:  92.22895341550031

# %%
centroids
# Out:
# array([[ 7.01324248e-01,  6.68417555e-01,  5.61603206e+00,
#         -7.18990301e+00,  5.33867735e-01,  2.02569499e-01,
#          1.80730693e-01,  8.62297274e-02,  2.06208577e-01,
#          5.04324088e-01,  1.60320361e+02,  2.24167763e+05,
#          3.97234469e+00,  9.01803607e-02],
#        [ 7.13513089e-01,  7.83295812e-01,  5.67844677e+00,
#         -9.19403752e+00,  5.68935428e-01,  7.84393106e-02,
#          4.76372028e-02,  7.98039442e-01,  1.53381065e-01,
#          2.05818237e-01,  1.31045402e+02,  4.11136096e+05,
#          3.95462478e+00,  9.35427574e-01]])

# %% [markdown]
# *****
